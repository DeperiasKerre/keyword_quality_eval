# %%
#!pip install openai==0.28.1
import openai
import os
from IPython.display import Markdown
api_key="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"

# %%
import openai

# Set your API key securely
openai.api_key = api_key

def chatWithGPT4(user_text, print_output=False):
    try:
        # Creating text completions using the updated `ChatCompletion` class
        response = openai.ChatCompletion.create(
            model="gpt-4",  # Easily switch between "gpt-3.5-turbo-0613", "gpt-4", "text-davinci-004", or others
            messages=[{"role": "system", "content": "You are a helpful assistant."},
                      {"role": "user", "content": user_text}],
            max_tokens=3000
        )
        text_output = response['choices'][0]['message']['content'] if response['choices'] else "No response generated."
        if print_output:
            print(text_output)
        return text_output
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

# %%
prompt="What are the state of the art methods in extracting specific domain information from text."

# %%
#prompt= "Can an Ontology to represent knowledge for a particular domain be considered an original contribution in computer science?"

# %%
print(prompt)
# Out:
# What are the state of the art methods in extracting specific domain information from text.

# %%
# Example usage
result = chatWithGPT4(prompt)
print(result)
# Out:
# Extracting domain-specific information from text is often used in fields like NLP, AI, machine learning, and data mining. Here are some state-of-the-art methods:
#
# 1. **Natural Language Processing (NLP)**: This method involves techniques like Named Entity Recognition (NER), part-of-speech (POS) tagging, chunking, and syntactic parsing to understand the semantic value of words and phrases in a given context. BERT, RoBERTa, and GPT-3 are some cutting-edge models used in NLP.
#
# 2. **Information Extraction (IE)**: Information Extraction systems search for specific types of entities and relations between those entities. Techniques like rule-based systems, supervised and semi-supervised learning, active learning, bootstrapped learning, and unsupervised learning are being used extensively for information extraction.
#
# ...
